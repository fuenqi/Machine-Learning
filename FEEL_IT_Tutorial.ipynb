# %% [markdown]
# <a href="https://colab.research.google.com/github/fuenqi/sentiment-analysis/blob/main/FEEL_IT_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FEEL-IT: Emotion and Sentiment Classification for the Italian Language
#
# Sentiment analysis and emotion classification for Italian using BERT (fine-tuning). Published at the Proceedings of the 11th Workshop on Computational Approaches to Subjectivity, Sentiment and Social Media Analysis (EACL2021).
#
# ## Abstract
#
# Sentiment analysis is a common task to understand people's reactions online. Still, we often need more nuanced information: is the post negative because the user is angry or because they are sad? An abundance of approaches has been introduced for tackling both tasks. However, at least for Italian, they all treat only one of the tasks at a time. We introduce FEEL-IT, a novel benchmark corpus of Italian Twitter posts annotated with four basic emotions: anger, fear, joy, sadness. By collapsing them, we can also do sentiment analysis. We evaluate our corpus on benchmark datasets for both emotion and sentiment classification, obtaining competitive results. We release an [open-source Python library](https://github.com/MilaNLProc/feel-it), so researchers can use a model trained on FEEL-IT for inferring both sentiments and emotions from Italian text.
#
# ![https://github.com/MilaNLProc/feel-it/actions](https://github.com/MilaNLProc/feel-it/workflows/Python%20package/badge.svg)
# ![https://pypi.python.org/pypi/feel_it](https://img.shields.io/pypi/v/feel_it.svg)
# ![https://lbesson.mit-license.org/](https://img.shields.io/badge/License-MIT-blue.svg)

# %% [markdown]
# ## Citation
#
# Please use the following bibtex entry if you use this model in your project:
#
# ```
# @inproceedings{bianchi2021feel,
#     title = {{"FEEL-IT: Emotion and Sentiment Classification for the Italian Language"}},
#     author = "Bianchi, Federico and Nozza, Debora and Hovy, Dirk",
#     booktitle = "Proceedings of the 11th Workshop on Computational Approaches to Subjectivity, Sentiment and Social Media Analysis",
#     year = "2021",
#     publisher = "Association for Computational Linguistics",
# }
# ```

# %% [markdown]
# ## HuggingFace Models
#
# You can find our HuggingFace models here:
#
#
# | Model                       | Download |
# | ------                      | -------------------------|
# | `feel-it-italian-sentiment` | [Link](https://huggingface.co/MilaNLProc/feel-it-italian-sentiment) |
# | `feel-it-italian-emotion`   | [Link](https://huggingface.co/MilaNLProc/feel-it-italian-emotion) |

# %% [markdown]
# ## How To Use

# %% [markdown]
# ### Installing

# %%
# %%capture
# !pip install feel-it

# %% [markdown]
# ### Emotion Classification

# %%
from feel_it import EmotionClassifier
emotion_classifier = EmotionClassifier()
# Out:
# Downloading:   0%|          | 0.00/899 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/794k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/299 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
import pandas as pd
df1 = pd.read_csv('/content/csv.csv',
                  encoding = 'latin1', index_col=0)

# %%
df1
# Out:
#        X                                                Url  \
# 1      0  https://twitter.com/liptrott_sarah/status/1512...
# 2      1  https://twitter.com/docNSC/status/151211230297...
# 3      2  https://twitter.com/lucadf/status/151210388994...
# 4      3  https://twitter.com/RasoiniR/status/1512103715...
# 5      4  https://twitter.com/USI_university/status/1511...
# ..   ...                                                ...
# 177  176  https://twitter.com/C_Balbi90/status/146471176...
# 178  177  https://twitter.com/MoroniGroup/status/1461601...
# 179  178  https://twitter.com/EnteOspedaliero/status/146...
# 180  179  https://twitter.com/EnteOspedaliero/status/146...
# 181  180  https://twitter.com/frbertoni/status/145882440...
#
#                       Datetime      Tweet.Id  \
# 1    2022-04-08 13:40:46+00:00  1.512430e+18
# 2    2022-04-07 16:57:21+00:00  1.512110e+18
# 3    2022-04-07 16:23:55+00:00  1.512100e+18
# 4    2022-04-07 16:23:14+00:00  1.512100e+18
# 5    2022-04-07 09:30:00+00:00  1.512000e+18
# ..                         ...           ...
# 177  2021-11-27 21:44:33+00:00  1.464710e+18
# 178  2021-11-19 07:46:58+00:00  1.461600e+18
# 179  2021-11-18 12:27:12+00:00  1.461310e+18
# 180  2021-11-16 08:40:40+00:00  1.460530e+18
# 181  2021-11-11 15:50:16+00:00  1.458820e+18
#
#                                                  Tweet  \
# 1    My colleague @AngelaTolotti presents the work ...
# 2    @lucadf @RasoiniR @RebeccaDeFiore @ilpensiero ...
# 3    @RasoiniR @docNSC @RebeccaDeFiore @ilpensiero ...
# 4    @docNSC @lucadf @RebeccaDeFiore @ilpensiero @f...
# 5    #USI #rewind??? \r\n???????? Il New England Jo...
# ..                                                 ...
# 177  Happy and proud to have the possibility to wor...
# 178  Don't miss the last day of @2021Termis. Wonder...
# 179  https://t.co/5wR57rR8YB il nuovo registro nazi...
# 180  ?? risaputo: la prevenzione ?? importante. Ecc...
# 181  I'm happy that our work on FLI1 targets in dif...
#
#                                          Cleaned.Tweet  Likes  Retweets  \
# 1    My colleague AngelaTolotti presents the work o...      0         0
# 2     lucadf RasoiniR RebeccaDeFiore ilpensiero for...      2         0
# 3     RasoiniR docNSC RebeccaDeFiore ilpensiero for...      3         0
# 4     docNSC lucadf RebeccaDeFiore ilpensiero forwa...      5         0
# 5     USI rewind Il New England Journal of Medicine...      1         1
# ..                                                 ...    ...       ...
# 177  Happy and proud to have the possibility to wor...      4         0
# 178  Don t miss the last day of Termis Wonderful sp...     33         6
# 179  https t co wR rR YB il nuovo registro nazional...      5         2
# 180   risaputo la prevenzione importante Ecco alcun...      8         3
# 181  I m happy that our work on FLI targets in diff...      8         1
#
#      Replies  Quotes             Platform         Username Coordinates  \
# 1          0       0             LinkedIn   liptrott_sarah         NaN
# 2          0       0   Twitter for iPhone           docNSC         NaN
# 3          1       0   Twitter for iPhone           lucadf         NaN
# 4          1       0   Twitter for iPhone         RasoiniR         NaN
# 5          0       0      Twitter Web App   USI_university         NaN
# ..       ...     ...                  ...              ...         ...
# 177        0       0  Twitter for Android        C_Balbi90         NaN
# 178        0       1      Twitter Web App      MoroniGroup         NaN
# 179        0       0      Twitter Web App  EnteOspedaliero         NaN
# 180        0       0      Twitter Web App  EnteOspedaliero         NaN
# 181        0       0      Twitter Web App        frbertoni         NaN
#
#      Polarity Polarity.Label  Subjectivity Subjectivity.Label
# 1    0.000000        Neutral      0.000000          Objective
# 2    0.000000        Neutral      0.000000          Objective
# 3    0.100000       Positive      1.000000         Subjective
# 4    0.000000        Neutral      0.000000          Objective
# 5    0.136364       Positive      0.454545         Subjective
# ..        ...            ...           ...                ...
# 177  0.800000       Positive      1.000000         Subjective
# 178  0.500000       Positive      0.522222         Subjective
# 179  0.100000       Positive      1.000000         Subjective
# 180  0.000000        Neutral      0.000000          Objective
# 181  0.304762       Positive      0.509524         Subjective
#
# [181 rows x 17 columns]

# %%
df1.columns
# Out:
# Index(['X', 'Url', 'Datetime', 'Tweet.Id', 'Tweet', 'Cleaned.Tweet', 'Likes',
#        'Retweets', 'Replies', 'Quotes', 'Platform', 'Username', 'Coordinates',
#        'Polarity', 'Polarity.Label', 'Subjectivity', 'Subjectivity.Label'],
#       dtype='object')

# %%
df1['Cleaned.Tweet']
# Out:
# 1      My colleague AngelaTolotti presents the work o...
# 2       lucadf RasoiniR RebeccaDeFiore ilpensiero for...
# 3       RasoiniR docNSC RebeccaDeFiore ilpensiero for...
# 4       docNSC lucadf RebeccaDeFiore ilpensiero forwa...
# 5       USI rewind Il New England Journal of Medicine...
#                              ...
# 177    Happy and proud to have the possibility to wor...
# 178    Don t miss the last day of Termis Wonderful sp...
# 179    https t co wR rR YB il nuovo registro nazional...
# 180     risaputo la prevenzione importante Ecco alcun...
# 181    I m happy that our work on FLI targets in diff...
# Name: Cleaned.Tweet, Length: 181, dtype: object

# %%
df1.iloc[0,]
# Out:
# 'My colleague @AngelaTolotti presents the work on #APN in #Palliative Care: clinical and faculty collaboration at the PROCare conference #enteospedalierocantonale @EnteOspedaliero ???????????????????????? https://t.co/xdPqI62NZd'

# %%
emotion_classifier.predict(list(df1['Cleaned.Tweet'].values))
# Out:
# ['joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'anger',
#  'joy',
#  'joy',
#  'fear',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'sadness',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'anger',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'anger',
#  'anger',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'anger',
#  'sadness',
#  'joy',
#  'fear',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'fear',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'anger',
#  'joy',
#  'anger',
#  'anger',
#  'anger',
#  'sadness',
#  'anger',
#  'anger',
#  'anger',
#  'fear',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy']

# %%
df1['Emotion'] = emotion_classifier.predict(list(df1['Cleaned.Tweet'].values))

# %%
df1.columns
df1.iloc[0,]
# Out:
# X                                                                     0
# Url                   https://twitter.com/liptrott_sarah/status/1512...
# Datetime                                      2022-04-08 13:40:46+00:00
# Tweet.Id                                          1512430000000000000.0
# Tweet                 My colleague @AngelaTolotti presents the work ...
# Cleaned.Tweet         My colleague AngelaTolotti presents the work o...
# Likes                                                                 0
# Retweets                                                              0
# Replies                                                               0
# Quotes                                                                0
# Platform                                                       LinkedIn
# Username                                                 liptrott_sarah
# Coordinates                                                         NaN
# Polarity                                                            0.0
# Polarity.Label                                                  Neutral
# Subjectivity                                                        0.0
# Subjectivity.Label                                            Objective
# Emotion                                                             joy
# Name: 1, dtype: object

# %% [markdown]
# ### Sentiment Classification

# %%
from feel_it import SentimentClassifier
sentiment_classifier = SentimentClassifier()
# Out:
# Downloading:   0%|          | 0.00/847 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/794k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/299 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
df1['sentiment'] = sentiment_classifier.predict(list(df1['Cleaned.Tweet'].values))
df1.columns
# Out:
# Index(['X', 'Url', 'Datetime', 'Tweet.Id', 'Tweet', 'Cleaned.Tweet', 'Likes',
#        'Retweets', 'Replies', 'Quotes', 'Platform', 'Username', 'Coordinates',
#        'Polarity', 'Polarity.Label', 'Subjectivity', 'Subjectivity.Label',
#        'Emotion', 'sentiment'],
#       dtype='object')
